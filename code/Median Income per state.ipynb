# %%
import pandas as pd

# %%
df = pd.read_excel('income.xlsx')
df
# Out:
#              State           2021      Unnamed: 2      2020 (41)  \
# 0              NaN  Median income  Standard error  Median income
# 1    United States          70784             368          68010
# 2          Alabama          56929            2294          54689
# 3           Alaska          81133            3967          74746
# 4          Arizona          70821            3394          67088
# ..             ...            ...             ...            ...
# 103       Virginia          80268            2953          86053
# 104     Washington          87648            3307          85157
# 105  West Virginia          46836            2247          54396
# 106      Wisconsin          69943            3133          70553
# 107        Wyoming          71052            3919          68506
#
#          Unnamed: 4           2019      Unnamed: 6           2018  \
# 0    Standard error  Median income  Standard error  Median income
# ...
