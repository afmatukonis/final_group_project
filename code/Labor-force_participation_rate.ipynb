# %%
import pandas as pd

# %%
df = pd.read_csv('Labor-force participation rate.csv')
df.head(10)
# Out:
#      Date     All   16-24   25-54   55-64     65+ Less than HS High school  \
# 0  Feb-23  62.30%  55.80%  82.60%  65.20%  19.20%       40.30%      58.20%
# 1  Jan-23  62.30%  55.60%  82.50%  65.20%  19.20%       40.20%      58.20%
# 2  Dec-22  62.20%  55.60%  82.40%  65.20%  19.20%       40.10%      58.20%
# 3  Nov-22  62.20%  55.60%  82.40%  65.10%  19.20%       40.10%      58.10%
# 4  Oct-22  62.20%  55.60%  82.40%  65.10%  19.20%       40.00%      58.10%
# 5  Sep-22  62.20%  55.70%  82.30%  65.00%  19.20%       40.00%      58.10%
# 6  Aug-22  62.10%  55.70%  82.20%  65.00%  19.10%       40.00%      58.00%
# 7  Jul-22  62.10%  55.60%  82.10%  65.00%  19.10%       40.00%      57.90%
# 8  Jun-22  62.00%  55.60%  82.10%  65.00%  19.10%       40.10%      57.80%
# 9  May-22  62.00%  55.60%  82.00%  65.00%  19.00%       40.00%      57.70%
#
#   Some college Bachelor's degree  ... White Men White Men 16-24  \
# 0       62.70%            73.00%  ...    66.10%          58.70%
# ...

# %%
df.dtypes
# Out:
# Date                           object
# All                            object
# 16-24                          object
# 25-54                          object
# 55-64                          object
#                                 ...
# White Men Less than HS         object
# White Men High school          object
# White Men Some college         object
# White Men Bachelor's degree    object
# White Men Advanced degree      object
# Length: 121, dtype: object
